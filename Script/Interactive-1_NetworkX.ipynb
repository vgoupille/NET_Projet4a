# %%
import os

print(os.getcwd())
# Out:
# /Users/valentingoupille/Library/Mobile Documents/com~apple~CloudDocs/University/Master_Bioinfo/NET/NET_Projet4a/Script

# %% [markdown]
# Connecté à myenvTEST (Python 3.11.10)

# %%
# read_graphml(path, node_type=<class 'str'>, edge_key_type=<class 'int'>, force_multigraph=False)
import networkx as nx

# Read the graph from a GraphML file
G = nx.read_graphml("../Data/reactome-77-reaction_R-HSA-5696021.graphml")

# Display basic info about the graph (number of nodes, edges, graph type)
print(f"Graph type: {type(G)}")
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")

# Access nodes and edges
print("Nodes:", G.nodes(data=True))  # 'data=True' shows node attributes
print("Edges:", G.edges(data=True))  # 'data=True' shows edge attributes
# Out:
# Graph type: <class 'networkx.classes.digraph.DiGraph'>
# Number of nodes: 10
# Number of edges: 9
# Nodes: [('BiochemicalReaction11477', {'type': 'BiochemicalReaction', 'label': 'ADPGK:Mg2+ phosphorylates Glc to G6P'}), ('SmallMolecule28', {'type': 'SmallMolecule', 'label': 'ADP'}), ('SmallMolecule98', {'type': 'SmallMolecule', 'label': 'AMP'}), ('SmallMolecule1321', {'type': 'SmallMolecule', 'label': 'G6P'}), ('SmallMolecule1222', {'type': 'SmallMolecule', 'label': 'Glc'}), ('Catalysis4341', {'type': 'Catalysis', 'label': ''}), ('Complex13985', {'type': 'Complex', 'label': 'ADPGK:Mg2+'}), ('SmallMolecule3167', {'type': 'SmallMolecule', 'label': 'Mg2+'}), ('Protein28996', {'type': 'Protein', 'label': 'ADPGK'}), ('Pathway2256', {'type': 'Pathway', 'label': 'Glycolysis'})]
# Edges: [('BiochemicalReaction11477', 'SmallMolecule28', {'type': 'left', 'label': 'left'}), ('BiochemicalReaction11477', 'SmallMolecule98', {'type': 'right', 'label': 'right'}), ('BiochemicalReaction11477', 'SmallMolecule1321', {'type': 'right', 'label': 'right'}), ('BiochemicalReaction11477', 'SmallMolecule1222', {'type': 'left', 'label': 'left'}), ('Catalysis4341', 'BiochemicalReaction11477', {'type': 'controlled', 'label': 'controlled'}), ('Catalysis4341', 'Complex13985', {'type': 'controller', 'label': 'controller'}), ('Complex13985', 'SmallMolecule3167', {'type': 'component', 'label': 'component'}), ('Complex13985', 'Protein28996', {'type': 'component', 'label': 'component'}), ('Pathway2256', 'BiochemicalReaction11477', {'type': 'pathwayComponent', 'label': 'pathwayComponent'})]

# %%
import matplotlib.pyplot as plt

# Read the graph from a GraphML file
G = nx.read_graphml("../Data/reactome-77-reaction_R-HSA-5218826.graphml")


# Save the plot in a folder (e.g., "Images" folder)
plt.savefig(
    "../Images/reactome_graph.png", format="png"
)  # You can change the format if needed

# Draw the graph
plt.figure(figsize=(10, 10))  # Adjust the figure size as needed
nx.draw(
    G,
    with_labels=True,
    node_color="lightblue",
    edge_color="gray",
    node_size=500,
    font_size=8,
)

# Show the plot
plt.show()
